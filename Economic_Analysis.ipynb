# %% [markdown]
# <a href="https://colab.research.google.com/github/ylmgrbzz/Economic-Data-Analysis-with-Python-Pandas-Matplotlib-From-FREDAPI/blob/main/Economic_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px 
plt.style.use("fivethirtyeight")
pd.set_option('max_columns',500)
color_pal=plt.rcParams["axes.prop_cycle"].by_key()["color"]

from fredapi import Fred

fred_key='ce654284b0727abc3524dd43126fafd3 '

# %%
# !pip install fredapi > /dev/null

# %%
fred = Fred(api_key=fred_key)

# %%
sp_search=fred.search('S&P' , order_by='popularity')
sp_search
# Out:
#                                 id realtime_start realtime_end  \
# series id
# BAMLH0A0HYM2          BAMLH0A0HYM2     2022-09-16   2022-09-16
# CSUSHPINSA              CSUSHPINSA     2022-09-16   2022-09-16
# BAMLH0A0HYM2EY      BAMLH0A0HYM2EY     2022-09-16   2022-09-16
# SP500                        SP500     2022-09-16   2022-09-16
# MEHOINUSA672N        MEHOINUSA672N     2022-09-16   2022-09-16
# ...                            ...            ...          ...
# RKNANPSEA666NRUG  RKNANPSEA666NRUG     2022-09-16   2022-09-16
# DDDI03PGA156NWDB  DDDI03PGA156NWDB     2022-09-16   2022-09-16
# DDDI02PKA156NWDB  DDDI02PKA156NWDB     2022-09-16   2022-09-16
# DDDI02CAA156NWDB  DDDI02CAA156NWDB     2022-09-16   2022-09-16
# HC01ESTVC1704013  HC01ESTVC1704013     2022-09-16   2022-09-16
#
#                                                               title  \
# series id
# BAMLH0A0HYM2      ICE BofA US High Yield Index Option-Adjusted S...
# ...

# %%
sp_search.shape
# Out:
# (1000, 15)

# %%
SP500=fred.get_series(series_id='SP500')
SP500.plot(figsize=(10,5),title='S&P 500',lw=2)

# %%
uemp_results=fred.search('unemployment')
uemp_results
# Out:
#                                           id realtime_start realtime_end  \
# series id
# UNRATE                                UNRATE     2022-09-16   2022-09-16
# UNRATENSA                          UNRATENSA     2022-09-16   2022-09-16
# NROU                                    NROU     2022-09-16   2022-09-16
# UNEMPLOY                            UNEMPLOY     2022-09-16   2022-09-16
# CCSA                                    CCSA     2022-09-16   2022-09-16
# ...                                      ...            ...          ...
# LAUMT053078000000003A  LAUMT053078000000003A     2022-09-16   2022-09-16
# LAUMT337495000000003A  LAUMT337495000000003A     2022-09-16   2022-09-16
# AUSURFEMQDSMEI                AUSURFEMQDSMEI     2022-09-16   2022-09-16
# AUSURFEMADSMEI                AUSURFEMADSMEI     2022-09-16   2022-09-16
# LMUNRLTTFRM647N              LMUNRLTTFRM647N     2022-09-16   2022-09-16
#
#                                                                    title  \
# ...

# %%
unrate=fred.get_series('UNRATE')
unrate.plot()

# %%
unemp_df=fred.search('unemployment rate state',filter=('frequency','Monthly'))

# %%
unemp_df
# Out:
#                       id realtime_start realtime_end  \
# series id
# UNRATE            UNRATE     2022-09-16   2022-09-16
# UNRATENSA      UNRATENSA     2022-09-16   2022-09-16
# UNEMPLOY        UNEMPLOY     2022-09-16   2022-09-16
# LNS14000006  LNS14000006     2022-09-16   2022-09-16
# U6RATE            U6RATE     2022-09-16   2022-09-16
# ...                  ...            ...          ...
# TNWILS0URN    TNWILS0URN     2022-09-16   2022-09-16
# LNU04024932  LNU04024932     2022-09-16   2022-09-16
# NCGUIL1URN    NCGUIL1URN     2022-09-16   2022-09-16
# ILKANK0URN    ILKANK0URN     2022-09-16   2022-09-16
# NCROCK0URN    NCROCK0URN     2022-09-16   2022-09-16
#
#                                                          title  \
# series id
# UNRATE                                       Unemployment Rate
# UNRATENSA                                    Unemployment Rate
# UNEMPLOY                                    Unemployment Level
# ...

# %%
unemp_df=unemp_df.query('seasonal_adjustment=="Seasonally Adjusted" and units=="Percent"')
unemp_df
# Out:
#                                 id realtime_start realtime_end  \
# series id
# UNRATE                      UNRATE     2022-09-16   2022-09-16
# LNS14000006            LNS14000006     2022-09-16   2022-09-16
# U6RATE                      U6RATE     2022-09-16   2022-09-16
# CAUR                          CAUR     2022-09-16   2022-09-16
# M0892AUSM156SNBR  M0892AUSM156SNBR     2022-09-16   2022-09-16
# ...                            ...            ...          ...
# LNS14000089            LNS14000089     2022-09-16   2022-09-16
# CNEWUR                      CNEWUR     2022-09-16   2022-09-16
# LNS13025701            LNS13025701     2022-09-16   2022-09-16
# LNS14000164            LNS14000164     2022-09-16   2022-09-16
# LNS14200000            LNS14200000     2022-09-16   2022-09-16
#
#                                                               title  \
# series id
# UNRATE                                            Unemployment Rate
# ...

# %%
unemp_df.loc[unemp_df['title'].str.contains('Unemployment Rate')]
# Out:
#                                 id realtime_start realtime_end  \
# series id
# UNRATE                      UNRATE     2022-09-16   2022-09-16
# LNS14000006            LNS14000006     2022-09-16   2022-09-16
# CAUR                          CAUR     2022-09-16   2022-09-16
# M0892AUSM156SNBR  M0892AUSM156SNBR     2022-09-16   2022-09-16
# LNS14000031            LNS14000031     2022-09-16   2022-09-16
# ...                            ...            ...          ...
# LRUNTTTTUSM156S    LRUNTTTTUSM156S     2022-09-16   2022-09-16
# LNS14000089            LNS14000089     2022-09-16   2022-09-16
# CNEWUR                      CNEWUR     2022-09-16   2022-09-16
# LNS14000164            LNS14000164     2022-09-16   2022-09-16
# LNS14200000            LNS14200000     2022-09-16   2022-09-16
#
#                                                               title  \
# series id
# UNRATE                                            Unemployment Rate
# ...

# %%
all_results=[]
for myid in unemp_df.index:
  results=fred.get_series(myid)
  results=results.to_frame(name=myid)
  all_results.append(results)
uemp_results=pd.concat(all_results,axis=1).drop(['M08310USM156SNBR','DSUR'], axis=1)

# %%
uemp_states=uemp_results.drop('UNRATE',axis=1)
uemp_states=uemp_states.dropna()
id_to_state=unemp_df['title'].str.replace('Unemployment Rate in','').to_dict()
uemp_states.columns=[id_to_state[c] for c in  uemp_states.columns]

# %%
uemp_states.isna().sum(axis=1)

# %%
px.line(uemp_states)

# %%
ax=uemp_states.loc[uemp_states.index =='2020-04-01'].T \
.sort_values('2020-04-01') \
.plot(kind='barh',figsize=(8, 12), width=0.7,  edgecolor='black', title="Nisan 2020'de Eyaletlere Göre İşsizlik Oranı")
ax.legend().remove()
plt.show()

# %%
part_df=fred.search('unemployment rate state',filter=('frequency','Monthly'))
part_df=part_df.query('seasonal_adjustment=="Seasonally Adjusted" and units=="Percent"')

# %%
part_df.shape
# Out:
# (160, 15)

# %%
part_id_to_state=part_df['title'].str.replace('Labor Force Participation Rate For','').to_dict()

all_results=[]
for myid in unemp_df.index:
  results=fred.get_series(myid)
  results=results.to_frame(name=myid)
  all_results.append(results)
part_states=pd.concat(all_results,axis=1)
part_states.columns=[id_to_state[c] for c in part_states.columns ]

# %%
uemp_states = uemp_states.rename(columns={'the District of Columbia':'District Of Columbia'})

# %%
fig, axs = plt.subplots(10, 5, figsize=(30, 30), sharex=True)
axs = axs.flatten()

i = 0
for state in uemp_states.columns:
    if state == "District Of Columbia":
        continue
    ax2 = axs[i].twinx()
    uemp_states.query('index >= 2020 and index < 2022')[state] \
        .plot(ax=axs[i], label='Unemployment')
    part_states.query('index >= 2020 and index < 2022')[state] \
        .plot(ax=ax2, label='Participation', color=color_pal[1])
    ax2.grid(False)
    axs[i].set_title(state)
    i += 1
plt.tight_layout()
plt.show()
